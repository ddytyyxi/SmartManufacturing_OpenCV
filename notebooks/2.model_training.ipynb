# %% [markdown]
# ■ Google drive **마운트**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ■ YOLO 학습을 위한 패키지 설치
# - ultralytics 패키지
# - opencv 패키지

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# ...

# %%
# @ 디버깅용
# 패키지가 정상적으로 설치되었는지 확인
import cv2
from ultralytics import YOLO
print("OpenCV version:", cv2.__version__)
print("Ultralytics 설치 완료!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# OpenCV version: 4.13.0
# Ultralytics 설치 완료!

# %% [markdown]
# ■ 학습 전, 데이터셋 파일 위치 확인

# %%
# !ls /content/drive/MyDrive/colab_backup/data/
# Out:
# data.yaml  test  train	validation

# %%
# 현재 data.yaml 내용 보기
# !cat /content/drive/MyDrive/colab_backup/data/data.yaml
# Out:
# train: /content/dataset/Data/train
# val: /content/dataset/Data/validation
# test: /content/dataset/Data/test
#
# nc: 8
# names: ['Cap1', 'Cap2', 'Cap3', 'Cap4', 'MOSFET', 'Mov', 'Resistor', 'Transformer']

# %%
# data.yaml 파일 내부 학습 파일 경로 수정
# 학습파일 -> train, validation, test
data_yaml_content = """
path: /content/drive/MyDrive/colab_backup/data
train: train
val: validation
test: test

nc: 8
names: ['Cap1', 'Cap2', 'Cap3', 'Cap4', 'MOSFET', 'Mov', 'Resistor', 'Transformer']
"""

# data.yaml 파일 저장
with open('/content/drive/MyDrive/colab_backup/data/data.yaml', 'w') as f:
    f.write(data_yaml_content)

print("✅ data.yaml 경로 수정 완료!")

# 수정된 내용 확인
print("\n 수정된 data.yaml 내용:")
# !cat /content/drive/MyDrive/colab_backup/data/data.yaml
# Out:
# ✅ data.yaml 경로 수정 완료!
#
#  수정된 data.yaml 내용:
#
# path: /content/drive/MyDrive/colab_backup/data
# train: train
# val: validation
# test: test
#
# nc: 8
# names: ['Cap1', 'Cap2', 'Cap3', 'Cap4', 'MOSFET', 'Mov', 'Resistor', 'Transformer']

# %% [markdown]
# ■ 객체 학습시키기

# %%
# !yolo train data='/content/drive/MyDrive/colab_backup/data/data.yaml' \
           model=yolov8n.pt \
           epochs=50 \
           imgsz=640 \
           name=train_corrected \
           save_dir=/content/runs/detect/train_corrected
# Out:
# ...
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ■ Google drive에 학습결과 마운트

# %%
import shutil

shutil.copytree(
    '/content/runs', # 생성된 학습결과 경로
    '/content/drive/MyDrive/colab_backup/runs'#Google drive에 마운트한 학습결과 경로
)
# Out:
# '/content/drive/MyDrive/colab_backup/runs'

# %% [markdown]
# ■ 마운트한 경로에 잘 들어갔는지 확인하는 코드

# %%
# !ls /content/drive/MyDrive/colab_backup/runs/detect/train_corrected # 마운트 잘 됐는지 확인
# Out:
# args.yaml			 results.csv	      val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	      val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg     val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch1.jpg     val_batch1_pred.jpg
# BoxR_curve.png			 train_batch2760.jpg  val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch2761.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch2762.jpg  weights
# labels.jpg			 train_batch2.jpg
